# %% [markdown]
# # 국민건강보험공단_건강검진정보_2021_12 분석
# 건강검진 결과지 제대로 읽는 법
#
#
# https://health.chosun.com/site/data/html_dir/2016/11/30/2016113001291.html

# %%
url1="https://raw.githubusercontent.com/KimYounghwan/bigdata/master/%EA%B5%AD%EB%AF%BC%EA%B1%B4%EA%B0%95%EB%B3%B4%ED%97%98%EA%B3%B5%EB%8B%A8_%EA%B1%B4%EA%B0%95%EA%B2%80%EC%A7%84%EC%A0%95%EB%B3%B4_20211229_1.CSV"
url2="https://raw.githubusercontent.com/KimYounghwan/bigdata/master/%EA%B5%AD%EB%AF%BC%EA%B1%B4%EA%B0%95%EB%B3%B4%ED%97%98%EA%B3%B5%EB%8B%A8_%EA%B1%B4%EA%B0%95%EA%B2%80%EC%A7%84%EC%A0%95%EB%B3%B4_20211229_2.CSV"
url3="https://raw.githubusercontent.com/KimYounghwan/bigdata/master/%EA%B5%AD%EB%AF%BC%EA%B1%B4%EA%B0%95%EB%B3%B4%ED%97%98%EA%B3%B5%EB%8B%A8_%EA%B1%B4%EA%B0%95%EA%B2%80%EC%A7%84%EC%A0%95%EB%B3%B4_20211229_3.CSV"
url4="https://raw.githubusercontent.com/KimYounghwan/bigdata/master/%EA%B5%AD%EB%AF%BC%EA%B1%B4%EA%B0%95%EB%B3%B4%ED%97%98%EA%B3%B5%EB%8B%A8_%EA%B1%B4%EA%B0%95%EA%B2%80%EC%A7%84%EC%A0%95%EB%B3%B4_20211229_4.CSV"

import pandas as pd

검진정보1=pd.read_csv(url1)
검진정보2=pd.read_csv(url2)
검진정보3=pd.read_csv(url3)
검진정보4=pd.read_csv(url4)

검진정보 = 검진정보1.append(검진정보2).append(검진정보3).append(검진정보4)

# %%
import pandas as pd

검진정보1=pd.read_csv(url1)
검진정보2=pd.read_csv(url2)
검진정보3=pd.read_csv(url3)
검진정보4=pd.read_csv(url4)

# %%
검진정보 = 검진정보1.append(검진정보2).append(검진정보3).append(검진정보4)
#검진정보

# %% [markdown]
# `검진정보 복사본 생성`

# %%
검진정보_copy = 검진정보.copy()
검진정보_copy
# Out:
#         기준년도  가입자 일련번호  시도코드  성별코드  연령대 코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 0       2020         1    36     1             9        165          60  72.1
# 1       2020         2    27     2            13        150          65  81.0
# 2       2020         3    11     2            12        155          55  70.0
# 3       2020         4    31     1            13        160          70  90.8
# 4       2020         5    41     2            12        155          50  75.2
# ...      ...       ...   ...   ...           ...        ...         ...   ...
# 249995  2020    999996    41     2            13        145          55  81.0
# 249996  2020    999997    26     2            12        160          55  76.5
# 249997  2020    999998    48     1             9        175          70  85.0
# 249998  2020    999999    48     2             9        160          70  91.0
# 249999  2020   1000000    28     1            11        160          55  76.1
#
# ...

# %% [markdown]
# `시도 코드 추가`

# %%
dic1 = {11 : '서울특별시',
26 : '부산광역시',
27 : '대구광역시',
28 : '인천광역시',
29 : '광주광역시',
30 : '대전광역시',
31 : '울산광역시',
36 : '세종특별자치시',
41 : '경기도',
42 : '강원도',
43 : '충청북도',
44 : '충청남도',
45 : '전라북도',
46 : '전라남도',
47 : '경상북도' ,
48 : '경상남도',
49 : '제주특별자치도'}

검진정보_copy['시도명'] = 검진정보_copy['시도코드'].apply(lambda x : dic1[x])
검진정보_copy.drop('시도코드', axis=1, inplace=True)
검진정보_copy.head(1)
#검진정보_copy
# Out:
#    기준년도  가입자 일련번호  성별코드  연령대 코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0  2020         1     1             9        165          60  72.1    1.2
#
#    시력(우)  청력(좌)  ...  (혈청지오티)AST  (혈청지오티)ALT  감마 지티피  흡연상태  음주여부  구강검진 수검여부  \
# 0    1.5    1.0  ...        21.0        27.0    21.0   1.0   0.0          0
#
#    치아우식증유무  치석    데이터 공개일자      시도명
# 0      NaN NaN  2021-12-29  세종특별자치시
#
# [1 rows x 31 columns]

# %% [markdown]
# `연령대 코드 추가`
# `2014년 이후 코드 사용`

# %%
age_list = ['0~4세','5~9세','10~14세',
                '15~19세','20~24세','25~29세',
                '30~34세','35~39세','40~44세',
                '45~49세','50~54세','55~59세',
                '60~64세','65~69세','70~74세',
               '75~79세','80~84세','85세 이상']
검진정보_copy['연령대'] = 검진정보_copy['연령대 코드(5세단위)'].apply(lambda x:age_list[x-1])
검진정보_copy.drop('연령대 코드(5세단위)', axis=1, inplace=True)
검진정보_copy.head(1)
#검진정보_copy
# Out:
#    기준년도  가입자 일련번호  성별코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0  2020         1     1        165          60  72.1    1.2    1.5    1.0
#
#    청력(우)  ...  (혈청지오티)ALT  감마 지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  치석  \
# 0    1.0  ...        27.0    21.0   1.0   0.0          0      NaN NaN
#
#      데이터 공개일자      시도명     연령대
# 0  2021-12-29  세종특별자치시  40~44세
#
# [1 rows x 31 columns]

# %% [markdown]
# `성별 칼럼 추가`

# %%
검진정보_copy['성별'] = 검진정보_copy['성별코드'].apply(lambda x:'남자' if x==1 else '여자')
검진정보_copy.drop('성별코드', axis=1, inplace=True)
검진정보_copy.head(1)
# Out:
#    기준년도  가입자 일련번호  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0  2020         1        165          60  72.1    1.2    1.5    1.0    1.0
#
#    수축기 혈압  ...  감마 지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  치석    데이터 공개일자  \
# 0   127.0  ...    21.0   1.0   0.0          0      NaN NaN  2021-12-29
#
#        시도명     연령대  성별
# 0  세종특별자치시  40~44세  남자
#
# [1 rows x 31 columns]

# %% [markdown]
# `사용하지 않는 칼럼 제거`

# %%
검진정보_copy.drop(['기준년도','가입자 일련번호','데이터 공개일자'], axis=1, inplace=True)
검진정보_copy.head(1)
# Out:
#    신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  수축기 혈압  이완기 혈압  \
# 0        165          60  72.1    1.2    1.5    1.0    1.0   127.0    79.0
#
#    식전혈당(공복혈당)  ...  (혈청지오티)ALT  감마 지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  치석  \
# 0        90.0  ...        27.0    21.0   1.0   0.0          0      NaN NaN
#
#        시도명     연령대  성별
# 0  세종특별자치시  40~44세  남자
#
# [1 rows x 28 columns]

# %%
검진정보_copy2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10676/81263281.py in <module>
# ----> 1 검진정보_copy2
#
# NameError: name '검진정보_copy2' is not defined

# %% [markdown]
# `시도명, 연령대, 성별 칼럼 맨 앞으로 가져오기`

# %%
검진정보_copy1 = 검진정보_copy[['시도명', '연령대', '성별']]
검진정보_copy2 = 검진정보_copy.loc[:,'신장(5Cm단위)':'치석']
검진정보_merge = pd.concat([검진정보_copy1, 검진정보_copy2], axis=1)
검진정보_merge.head(1)

# merge한 데이터 검진정보_copy에 저장
검진정보_copy = 검진정보_merge.copy()
#검진정보_copy

# %% [markdown]
# ### 질병 분류 작업

# %% [markdown]
# `이상지질 혈증 분류`
#
# 검진항목 : HDL, LDL
# 조사항목 : 콜레스테롤 수치
#
# HDL 정상수치 :  60mg/dL<=HDL &  LDL>=160mg/dL
# LDL 정상수치 :  130mg/dL>=HDL &  LDL<=130mg/dL
#
# 저HDL콜레스테롤혈증(HDL-C 남성＜40 mg/dL, 여성＜50 mg/dL)
#
# 이상지질혈증
# 1. 고콜레스테롤혈증, 고중성지방혈증
# 2. 고LDL콜레스테롤혈증, 저HDL콜레스테롤혈증  =>  둘 중 하나라도 해당하면 이상지질혈증
#
#
# + 당뇨병과 이상지질혈증 관계
# >메디칼업저버(http://www.monews.co.kr)

# %% [markdown]
# `당뇨병 분류`
#
# 검진항목 : 공복 혈당
# 조사항목 : 혈당 수치
# 정상 : 70~120 mg/dL
# 공복혈당장애 : 100-125 mg/dL
# 당뇨 : 126mg/dL 이상

# %% [markdown]
# ### 여기서부터 코드 실행하시면 됩니다!

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

url1="https://raw.githubusercontent.com/KimYounghwan/bigdata/master/%EA%B5%AD%EB%AF%BC%EA%B1%B4%EA%B0%95%EB%B3%B4%ED%97%98%EA%B3%B5%EB%8B%A8_%EA%B1%B4%EA%B0%95%EA%B2%80%EC%A7%84%EC%A0%95%EB%B3%B4_20211229_1.CSV"
url2="https://raw.githubusercontent.com/KimYounghwan/bigdata/master/%EA%B5%AD%EB%AF%BC%EA%B1%B4%EA%B0%95%EB%B3%B4%ED%97%98%EA%B3%B5%EB%8B%A8_%EA%B1%B4%EA%B0%95%EA%B2%80%EC%A7%84%EC%A0%95%EB%B3%B4_20211229_2.CSV"
url3="https://raw.githubusercontent.com/KimYounghwan/bigdata/master/%EA%B5%AD%EB%AF%BC%EA%B1%B4%EA%B0%95%EB%B3%B4%ED%97%98%EA%B3%B5%EB%8B%A8_%EA%B1%B4%EA%B0%95%EA%B2%80%EC%A7%84%EC%A0%95%EB%B3%B4_20211229_3.CSV"
url4="https://raw.githubusercontent.com/KimYounghwan/bigdata/master/%EA%B5%AD%EB%AF%BC%EA%B1%B4%EA%B0%95%EB%B3%B4%ED%97%98%EA%B3%B5%EB%8B%A8_%EA%B1%B4%EA%B0%95%EA%B2%80%EC%A7%84%EC%A0%95%EB%B3%B4_20211229_4.CSV"

import pandas as pd

검진정보1=pd.read_csv(url1)
검진정보2=pd.read_csv(url2)
검진정보3=pd.read_csv(url3)
검진정보4=pd.read_csv(url4)

검진정보 = 검진정보1.append(검진정보2).append(검진정보3).append(검진정보4)


검진정보 = 검진정보1.append(검진정보2).append(검진정보3).append(검진정보4)
df = 검진정보.copy()
df

dic1 = {11 : '서울특별시',
26 : '부산광역시',
27 : '대구광역시',
28 : '인천광역시',
29 : '광주광역시',
30 : '대전광역시',
31 : '울산광역시',
36 : '세종특별자치시',
41 : '경기도',
42 : '강원도',
43 : '충청북도',
44 : '충청남도',
45 : '전라북도',
46 : '전라남도',
47 : '경상북도' ,
48 : '경상남도',
49 : '제주특별자치도'}


age_list = ['0~4세','5~9세','10~14세',
                '15~19세','20~24세','25~29세',
                '30~34세','35~39세','40~44세',
                '45~49세','50~54세','55~59세',
                '60~64세','65~69세','70~74세',
               '75~79세','80~84세','85세 이상']

# 코드 변환 후 새로운 칼럼 추가, 기존 코드 칼럼 삭제
df['시도명'] = df['시도코드'].apply(lambda x : dic1[x])
df.drop('시도코드', axis=1, inplace=True)
df['연령대'] = df['연령대 코드(5세단위)'].apply(lambda x:age_list[x-1])
df.drop('연령대 코드(5세단위)', axis=1, inplace=True)
df['성별'] = df['성별코드'].apply(lambda x:'남자' if x==1 else '여자')
df.drop('성별코드', axis=1, inplace=True)

# 필요없는 칼럼 삭제
df.drop(['기준년도','가입자 일련번호','데이터 공개일자'], axis=1, inplace=True)

#시도명, 연령대, 성별 칼럼 맨 앞으로 가져오기
검진정보_copy1 = df[['시도명', '연령대', '성별']]
검진정보_copy2 = df.loc[:,'신장(5Cm단위)':'치석']
검진정보_merge = pd.concat([검진정보_copy1, 검진정보_copy2], axis=1)
검진정보_merge = 검진정보_merge.reset_index(drop = True) 


# merge한 데이터 검진정보_copy에 저장
df = 검진정보_merge.copy()

#당뇨병 
df['당뇨병'] = '의심'
con1 = (df['식전혈당(공복혈당)'] >= 126)
con2 = (df['식전혈당(공복혈당)'] <= 120) & (df['식전혈당(공복혈당)'] >= 70)
con3 = df['식전혈당(공복혈당)'].isnull()
df.loc[con1,"당뇨병"] = '비정상'
df.loc[con2, '당뇨병'] = '정상'
df.loc[con3, '당뇨병'] = '미관측'

#저혈당
# http://www.samsunghospital.com/dept/main/index.do?DP_CODE=DM&MENU_ID=008037
df['저혈당']= '정상'
con1 = (df['식전혈당(공복혈당)'] < 70)
con2 = (df['식전혈당(공복혈당)'].isnull())
df.loc[con1,"저혈당"] = '비정상'
df.loc[con2,"저혈당"] = '미관측'

# 간 기능 이상
df['간 기능 이상'] = '의심'
con1 = ((df['(혈청지오티)AST'] >= 51)|(df['(혈청지오티)ALT'] >= 46))
con2 = ((df['(혈청지오티)AST'] <= 32) & (df['(혈청지오티)ALT'] <= 32))
con3 = (df['(혈청지오티)AST'].isnull()) & (df['(혈청지오티)ALT'].isnull())
df.loc[con1,'간 기능 이상'] = '비정상'
df.loc[con2,'간 기능 이상'] = '정상'
df.loc[con3, '간 기능 이상'] = '미관측'

#고혈압
df['고혈압']= '의심'
con1 = (df['수축기 혈압'] < 120) & (df['이완기 혈압'] < 80)
con2 = (df['수축기 혈압'] >= 145) | (df['이완기 혈압'] >=95)
con3 = (df['수축기 혈압'].isnull()) | (df['이완기 혈압'].isnull())
df.loc[con1,"고혈압"] = '정상'
df.loc[con3,"고혈압"] = '미관측'
df.loc[con2,"고혈압"] = '비정상'

#저혈압 
#https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=32144
df["저혈압"] = '미관측'
con1 = (df['수축기 혈압'] < 120) & (df['이완기 혈압'] < 80) #정상
con2 = (df['수축기 혈압'] < 100)  & (df['이완기 혈압'] < 60) #비정상
con3 = (df['수축기 혈압'].isnull()) | (df['이완기 혈압'].isnull()) | (df['수축기 혈압'] >= 120) & (df['이완기 혈압'] >= 80)#미관측

df.loc[con1,"저혈압"] = '정상'
df.loc[con3,"저혈압"] = '미관측'
df.loc[con2,"저혈압"] = '비정상'

# 이상지질혈증
df['이상지질혈증HDL'] = df['HDL 콜레스테롤'].apply(lambda x:'yes' if 60 > x else 'no')
df['이상지질혈증LDL'] = df['LDL 콜레스테롤'].apply(lambda x:'yes' if 130 < x else 'no')

df['이상지질혈증'] = '미관측'

HDLcon = df['이상지질혈증HDL']=='yes'
LDLcon = df['이상지질혈증LDL']=='yes'
df.loc[HDLcon|LDLcon, '이상지질혈증'] = '비정상'

con1 = df['HDL 콜레스테롤'].isnull()
con2 = df['LDL 콜레스테롤'].isnull()
df.loc[con1,'이상지질혈증HDL'] = '미관측'
df.loc[con2,'이상지질혈증LDL'] = '미관측'

HDLcon2 = df['이상지질혈증HDL']=='no'
LDLcon2 = df['이상지질혈증LDL']=='no'
df.loc[HDLcon2&LDLcon2, '이상지질혈증'] = '정상'

# 비만
BMI = df['체중(5Kg 단위)'] / (df['신장(5Cm단위)']*0.01)**2
cond1 = (BMI <= 18.5)
cond2 = ((BMI > 18.5) & (BMI <= 23.0))
cond3 = ((BMI > 23.0) & (BMI <= 25.0))
cond4 = (BMI > 25.0)

df.loc[cond1, '비만'] = "저체중"
df.loc[cond2, '비만'] = "정상"
df.loc[cond3, '비만'] = "과체중"
df.loc[cond4, '비만'] = "고도비만"

df.head(1)
# Out:
#        시도명     연령대  성별  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0  세종특별자치시  40~44세  남자        165          60  72.1    1.2    1.5    1.0
#
#    청력(우)  ...  치석  당뇨병  저혈당  간 기능 이상  고혈압  저혈압  이상지질혈증HDL  이상지질혈증LDL  이상지질혈증  \
# 0    1.0  ... NaN   정상   정상       정상   의심  미관측        yes         no     비정상
#
#    비만
# 0  정상
#
# [1 rows x 37 columns]

# %%
d_columns = df2.columns[5:]
new1 = df2.groupby('성별')[d_columns].mean()
new1 = new1.reset_index()
new_df1 = pd.DataFrame(new1.iloc[0,:])
new_df2 = pd.DataFrame(new1.iloc[1,:])
new_df1.drop(new_df1.index[0], inplace=True)
new_df1.columns = ['수치']
new_df1['성별'] = '남자'
new_df1_index = new_df1.index

new_df1_1 = pd.DataFrame(new_df1_index)
new_df1= new_df1.reset_index()
new_df남자 = pd.concat([new_df1, new_df1_1], axis=1)
new_df남자
new_df남자.drop(0, inplace=True, axis=1)
new_df남자.columns = ['질병', '수치','성별']
new_df남자


new_df2.drop(new_df2.index[0], inplace=True)
new_df2.columns = ['수치']
new_df2['성별'] = '여자'
new_df2_index = new_df2.index

new_df2_1 = pd.DataFrame(new_df2_index)
new_df2= new_df2.reset_index()
new_df여자 = pd.concat([new_df2, new_df2_1], axis=1)
new_df여자
new_df여자.drop(0, inplace=True, axis=1)
new_df여자.columns = ['질병', '수치','성별']
new_df여자

final_df = pd.concat([new_df남자,new_df여자])
final_df

plt.figure(figsize=(20,8))
sns.barplot(data=final_df, x='질병', y='수치', hue='성별', palette=['blue','red'], alpha=0.8)
plt.xticks(rotation =45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10676/431356143.py in <module>
#      35
#      36 plt.figure(figsize=(20,8))
# ---> 37 sns.barplot(data=final_df, x='질병', y='수치', hue='성별', palette=['blue','red'], alpha=0.8)
#      38 plt.xticks(rotation =45)
#      39 plt.show()
#
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# ...

# %% [markdown]
# ### 성별 인원수 비교

# %%
# 연령대, 성별 인원수                    시도명은 전체 인원수를 구하기 위한 임의의 칼럼
df성별추이 = pd.DataFrame()
df성별추이['인원수'] = df.groupby(['연령대','성별'])[['시도명']].count()
df성별추이
# Out:
#              인원수
# 연령대    성별
# 40~44세 남자  88435
#        여자  67842
# 45~49세 남자  79273
#        여자  64892
# 50~54세 남자  89189
#        여자  86516
# 55~59세 남자  71546
#        여자  70543
# 60~64세 남자  74559
#        여자  80537
# 65~69세 남자  42437
#        여자  44216
# 70~74세 남자  35450
#        여자  38264
# 75~79세 남자  17037
#        여자  19626
# 80~84세 남자  10433
#        여자  12968
# 85세 이상 남자   2330
#        여자   3907

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='연령대', hue='성별', data=df, palette='coolwarm')
plt.show()

# %%
age1 = ((df['연령대'] == '40~44세') | (df['연령대'] == '45~49세'))
age2 = ((df['연령대'] == '50~54세') | (df['연령대'] == '55~59세') | (df['연령대'] == '60~64세'))
age3 = ((df['연령대'] == '65~69세') | (df['연령대'] == '70~74세') | (df['연령대'] == '75~79세') | (df['연령대'] == '80~84세') | (df['연령대'] =='85세 이상'))

df.loc[age1,'연령대'] = '중년'
df.loc[age2,'연령대'] = '장년'
df.loc[age3,'연령대'] = '노년'

df.head(1)
# Out:
#        시도명 연령대  성별  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0  세종특별자치시  중년  남자        165          60  72.1    1.2    1.5    1.0    1.0
#
#    ...  치석  당뇨병  저혈당  간 기능 이상  고혈압  저혈압  이상지질혈증HDL  이상지질혈증LDL  이상지질혈증  비만
# 0  ... NaN   정상   정상       정상   의심  미관측        yes         no     비정상  정상
#
# [1 rows x 37 columns]

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='연령대', hue='성별', data=df, palette='coolwarm')
plt.show()

# %% [markdown]
# ### 성별, 연령대별 비만 인원수

# %%
# 비만 조건
비만con = ~((df['비만']=='정상') | (df['비만']=='저체중'))
# 비만인의 연령대별, 성별 인원수
# 595504 / 1000000
df비만 = df[비만con].pivot_table(index=['연령대', '성별'], values='비만', aggfunc='count',
                     margins=True,margins_name='총계')
# 40~70세 미만 연령대에서 비만 남성 인원이 여성 인원보다 많다. 70세 이후부터 여성 비만 비율 높아진다.
df비만['비만비율'] = round(df비만['비만']/1000000 * 100, 2)
df비만
# Out:
#             비만   비만비율
# 연령대 성별
# 노년  남자   68167   6.82
#     여자   70236   7.02
# 장년  남자  164120  16.41
#     여자  117907  11.79
# 중년  남자  122583  12.26
#     여자   52491   5.25
# 총계      595504  59.55

# %%
df비만 = df[비만con].pivot_table(index=['성별'], values='비만', aggfunc='count', columns='연령대')
# 40~70세 미만 연령대에서 비만 남성 인원이 여성 인원보다 많다. 70세 이후부터 여성 비만 비율 높아진다.
#df비만['비만비율'] = round(df비만['비만']/1000000 * 100, 2)
df비만
# Out:
# 연령대     노년      장년      중년
# 성별
# 남자   68167  164120  122583
# 여자   70236  117907   52491

# %%
colors = sns.color_palette('winter',3) ## 색상 지정
df비만 = df비만.reindex(columns=['중년', '장년', '노년'])
ax = df비만.plot(kind='bar',  title="연령별 성별 비만 분포", color=colors, edgecolor=colors, alpha=0.6)
plt.ylabel('비만 인원')
plt.xticks(rotation =0)
plt.show()

# %% [markdown]
# ### 연령대별, 성별 고혈압

# %%
# 고혈압 조건
고혈압con = (df['고혈압']=='비정상')

# 고혈압인의 연령대별, 성별 인원수
# 126743 / 1000000
df고혈압 = df[고혈압con].pivot_table(index=['연령대', '성별'], values='고혈압', aggfunc='count',
                     margins=True,margins_name='총계')

# 40~65세 미만까지 여성보다 남성 인원수가 많고, 65세 이후부터 여성 고혈압 인원이 많아진다.
df고혈압['고혈압비율'] = round(df고혈압['고혈압']/1000000 * 100, 2)
df고혈압
# Out:
#            고혈압  고혈압비율
# 연령대 성별
# 노년  남자   16326   1.63
#     여자   19854   1.99
# 장년  남자   25374   2.54
#     여자   18831   1.88
# 중년  남자   15453   1.55
#     여자    5473   0.55
# 총계      101311  10.13

# %%
df고혈압 = df[고혈압con].pivot_table(index=['성별'], values='고혈압', aggfunc='count', columns='연령대')
df고혈압 = df고혈압.reindex(columns=['중년', '장년', '노년'])
df고혈압
# Out:
# 연령대     중년     장년     노년
# 성별
# 남자   15453  25374  16326
# 여자    5473  18831  19854

# %%
df고혈압 = df[고혈압con].pivot_table(index=['성별'], values='고혈압', aggfunc='count', columns='연령대')
df고혈압 = df고혈압.reindex(columns=['중년', '장년', '노년'])
df고혈압
colors = sns.color_palette('winter',3) ## 색상 지정
ax = df고혈압.plot(kind='bar',  title="연령별 성별 고혈압 분포", color=colors, edgecolor=colors, alpha=0.6)
plt.ylabel('고혈압 인원')
plt.xticks(rotation =0)
plt.show()

# %%
df고혈압.plot.bar(stacked=True, rot=0)

plt.title('Stacked Bar Chart by Pandas', fontsize=20)

plt.show()

# %%
# sum_by_male = df고혈압.loc[df고혈압.index=='남자', :].sum().sum()
# sum_by_female = df고혈압.loc[df고혈압.index=='여자', :].sum().sum()

# %%
# label = ['고혈압']
# #N = len(tips['day'].unique())
# N = 1
# index = np.arange(N)
# alpha = 0.5

# p1 = plt.bar(index, sum_by_male, color='b', alpha=alpha)
# p2 = plt.bar(index, sum_by_female, color='r', alpha=alpha,
#              bottom=sum_by_male) # stacked bar chart

# plt.title('성별 연령별 고혈압 인원', fontsize=20)
# plt.ylabel('고혈압 인원', fontsize=18)
# plt.xlabel('고혈압', fontsize=18)
# plt.xticks(index, label, fontsize=15)
# plt.legend((p1[0], p2[0]), ('Male', 'Female'), fontsize=15)
# plt.show()

# %%
# bar_width = 0.35

# alpha = 0.5
# p1 = plt.bar(index, sum_by_male, 

#              bar_width, 
#              color='b', 
#              alpha=alpha,
#              label='Male')

# p2 = plt.bar(index + bar_width, sum_by_female, 

#              bar_width, 
#              color='r', 
#              alpha=alpha,
#              label='Female')



# plt.title('Dodged Bar Chart of Sum of Tips by Day & Sex', fontsize=20)

# plt.ylabel('Sum of Tips', fontsize=18)

# plt.xlabel('Day', fontsize=18)

# plt.xticks(index, label, fontsize=15)

# plt.legend((p1[0], p2[0]), ('Male', 'Female'), fontsize=15)

# plt.show()

# %%
df고혈압['노년']
# Out:
# 성별
# 남자    16326
# 여자    19854
# Name: 노년, dtype: int64

# %%
# Altair 설치방법
# conda install -c conda-forge altair vega_datasets vega

import pandas as pd
import numpy as np
import altair as alt

df1=pd.DataFrame(df고혈압.iloc[1,],index=["A","B","C"],columns=["남자", '여자'])
df2=pd.DataFrame(10*np.random.rand(3,2),index=["A","B","C"],columns=["남자", '여자'])

def prep_df(df, name):
    df = df.stack().reset_index()
    df.columns = ['c1', '성별', '수치']
    df['수치'] = name
    return df

df1 = prep_df(df1, 'DF1') 
df2 = prep_df(df2, 'DF2') 

df_ = pd.concat([df1, df2])

alt.Chart(df_).mark_bar().encode(
    x=alt.X('c2:N', title=None),
    y=alt.Y('sum(values):Q', axis=alt.Axis(grid=False, title=None)),
    column=alt.Column('c1:N', title=None),
    color=alt.Color('DF:N', scale=alt.Scale(range=['#96ceb4', '#ffcc5c','#ff6f69']))
).configure_view(
    strokeOpacity=0    
)
# Out:
# alt.Chart(...)

# %%
# df고혈압 = df[고혈압con].pivot_table(index=['성별'], values='고혈압', aggfunc='count', columns='연령대')
# df고혈압 = df고혈압.reindex(columns=['중년', '장년', '노년'])
# df고혈압['남자']

# %%
df
# Out:
#             시도명 연령대  성별  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 0       세종특별자치시  중년  남자        165          60  72.1    1.2    1.5    1.0
# 1         대구광역시  장년  여자        150          65  81.0    0.8    0.8    1.0
# 2         서울특별시  장년  여자        155          55  70.0    0.6    0.7    1.0
# 3         울산광역시  장년  남자        160          70  90.8    1.0    1.0    1.0
# 4           경기도  장년  여자        155          50  75.2    1.5    1.2    1.0
# ...         ...  ..  ..        ...         ...   ...    ...    ...    ...
# 999995      경기도  장년  여자        145          55  81.0    0.9    1.0    1.0
# 999996    부산광역시  장년  여자        160          55  76.5    1.5    1.5    1.0
# 999997     경상남도  중년  남자        175          70  85.0    1.2    1.2    1.0
# 999998     경상남도  중년  여자        160          70  91.0    0.6    0.5    1.0
# 999999    인천광역시  장년  남자        160          55  76.1    2.0    2.0    1.0
#
#         청력(우)  ...   치석  당뇨병  저혈당  간 기능 이상  고혈압  저혈압  이상지질혈증HDL  이상지질혈증LDL  \
# ...

# %% [markdown]
# ### 연령대별, 성별 저혈압

# %% [markdown]
# 저혈압과 냉증, 유독 여성에게 많은 이유는?
#
# 여성 저혈압환자에게서 주로 발생하는 증상인 수족냉증의 경우는
# 추위를 느끼지 않을 만한 온도에서 손이나 발에 심한 냉기를 느끼는 증상이다.
# 원인이 다양하나 주로 말초혈관에 혈액순환이 잘 이뤄지지 않아 나타나는 경우가 많다.
# 특히 여성의 경우 생리, 임신, 출산, 폐경과 같은 여성 호르몬의 변화가 자율신경계에 영향을 준다.

# %%
# 저혈압 조건
저혈압con = (df['저혈압']=='비정상')

# 고혈압인의 연령대별, 성별 인원수
# 126743 / 1000000
df저혈압 = df[저혈압con].pivot_table(index=['연령대', '성별'], values='저혈압', aggfunc='count',
                     margins=True,margins_name='총계')

# 40~75세 미만까지 저혈압 여성이 남성보다 많고, 75세 이후부터 남성 저혈압 많아진다.
df저혈압['저혈압비율'] = round(df저혈압['저혈압']/1000000 * 100, 2)
df저혈압

# %%
df저혈압 = df[저혈압con].pivot_table(index=['성별'], values='저혈압', aggfunc='count', columns='연령대')
colors = sns.color_palette('winter',3) ## 색상 지정

df저혈압 = df저혈압.reindex(columns=['중년', '장년', '노년'])
ax = df저혈압.plot(kind='bar',  title="연령별 성별 저혈압 분포", color=colors, edgecolor=colors, alpha=0.6)
plt.ylabel('저혈압 인원')
plt.xticks(rotation =0)
plt.show()

# %% [markdown]
# ### 연령대별, 성별 당뇨병

# %%
# 당뇨병 조건
당뇨병con = (df['당뇨병']=='비정상')

# 당뇨병인의 연령대별, 성별 인원수
# 105231 / 1000000
df당뇨병 = df[당뇨병con].pivot_table(index=['연령대', '성별'], values='당뇨병', aggfunc='count',
                     margins=True,margins_name='총계')

# 40세부터 80세 미만까지 남성 당뇨인원이 더 많고, 80세 이후부터 여성 당뇨환자 비율이 높아진다.
df당뇨병['당뇨병비율'] = round(df당뇨병['당뇨병']/1000000 * 100, 2)
df당뇨병

# %%
df당뇨병 = df[당뇨병con].pivot_table(index=['성별'], values='당뇨병', aggfunc='count', columns='연령대')
colors = sns.color_palette('winter',3) ## 색상 지정
df당뇨병 = df당뇨병.reindex(columns=['중년', '장년', '노년'])
ax = df당뇨병.plot(kind='bar',  title="연령별 성별 당뇨병 분포", color=colors, edgecolor=colors, alpha=0.6)
plt.ylabel('당뇨병 인원')
plt.xticks(rotation =0)
plt.show()

# %% [markdown]
# ### 연령대별, 성별 저혈당

# %%
# 저혈당 조건
저혈당con = (df['저혈당']=='비정상')

# 저혈당인의 연령대별, 성별 인원수
#  / 1000000
df저혈당 = df[저혈당con].pivot_table(index=['연령대', '성별'], values='저혈당', aggfunc='count',
                     margins=True,margins_name='총계')

# 40세부터 65세 미만 여성이 남성보다 저혈당 인원이 많다.
df저혈당['저혈당비율'] = round(df저혈당['저혈당']/1000000 * 100, 2)
df저혈당

# %%
df저혈당 = df[저혈당con].pivot_table(index=['성별'], values='저혈당', aggfunc='count', columns='연령대')
colors = sns.color_palette('winter',3) ## 색상 지정
df저혈당 = df저혈당.reindex(columns=['중년', '장년', '노년'])
ax = df저혈당.plot(kind='bar',  title="연령별 성별 저혈당 분포", color=colors, edgecolor=colors, alpha=0.6)
plt.ylabel('저혈당 인원')
plt.xticks(rotation =0)
plt.show()

# %% [markdown]
# ### 연령대별, 성별 간 기능 이상

# %%
# 간 기능 이상 조건
간con = (df['간 기능 이상']=='비정상')

# 간 기능 이상인의 연령대별, 성별 인원수
# 109985 / 1000000
df간 = df[간con].pivot_table(index=['연령대', '성별'], values='간 기능 이상', aggfunc='count',
                     margins=True,margins_name='총계')

# 85세 이상을 제외하고 모든 연령대에서 남성의 간 기능 이상 비율이 높다.
df간['간기능이상비율'] = round(df간['간 기능 이상']/1000000 * 100, 2)
df간

# %%
df간 = df[간con].pivot_table(index=['성별'], values='간 기능 이상', aggfunc='count', columns='연령대')
colors = sns.color_palette('winter',3) ## 색상 지정
df간 = df간.reindex(columns=['중년', '장년', '노년'])
ax = df간.plot(kind='bar',  title="연령별 성별 간 기능 이상 분포", color=colors, edgecolor=colors, alpha=0.6)
plt.ylabel('간 기능 이상 인원')
plt.xticks(rotation =0)
plt.show()

# %% [markdown]
# ### 연령대별, 성별 이상지질혈증

# %%
# 이상지질혈증 조건
이상지질혈증con = (df['이상지질혈증']=='비정상')

# 이상지질혈증의 연령대별, 성별 인원수
# 302058 / 1000000
df이상지질혈증 = df[이상지질혈증con].pivot_table(index=['연령대', '성별'], values='이상지질혈증', aggfunc='count',
                     margins=True,margins_name='총계')

# 이상지질혈증은 장년층에서 주로 나타난다.
df이상지질혈증['이상지질혈증비율'] = round(df이상지질혈증['이상지질혈증']/1000000 * 100, 2)
df이상지질혈증

# %%
df이상지질혈증 = df[이상지질혈증con].pivot_table(index=['성별'], values='이상지질혈증', aggfunc='count', columns='연령대')
colors = sns.color_palette('winter',3) ## 색상 지정
df이상지질혈증 = df이상지질혈증.reindex(columns=['중년', '장년', '노년'])
ax = df이상지질혈증.plot(kind='bar',  title="연령별 성별 이상지질혈증 분포", color=colors, edgecolor=colors, alpha=0.6)
plt.ylabel('이상지질혈증 인원')
plt.xticks(rotation =0)
plt.show()
